# %% [markdown]
# ## 우리동네 인구 구조 시각화하기

# %%
import csv
import matplotlib.pyplot as plt

class spread_of_pops:
    def __init__(self, csv_path):
        self.csv_path = csv_path

    def read_local_data(self, local_name):
        f = open('age.csv')
        data = csv.reader(f)

        # 검색되는 지역명의 Row 가 여러개인 경우 잘못된 자료가 나오는 것을 방지하기 위해 
        # 0~100까지 나이별 Array 를 만들고 해당 방에 값을 계속 누적하여 보여준다.
        self.spread_ages = []
        for i in range(101):
            self.spread_ages.append(0)

        for row in data:
            if (local_name in row[0]):
                idx = 0
                for i in row[3:]:
                    n = i.replace(',','')
                    self.spread_ages[idx] += int(n)
                    idx += 1
        
        f.close()
    
    def show(self, style = 'ggplot'):
        plt.style.use(style)
        plt.plot(self.spread_ages)
        plt.show()
        
    def row(self):
        print(self.spread_ages)

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
sp = spread_of_pops('age.csv')

# %%
sp.read_local_data('신도림')
sp.row()
sp.show()
# Out:
# [326, 334, 406, 413, 389, 408, 417, 434, 411, 387, 420, 383, 354, 357, 340, 338, 349, 339, 407, 380, 390, 453, 424, 516, 451, 466, 448, 484, 471, 476, 558, 541, 579, 619, 638, 740, 756, 792, 745, 789, 671, 687, 700, 636, 726, 691, 657, 619, 649, 585, 579, 470, 522, 534, 563, 445, 511, 569, 572, 513, 532, 456, 426, 497, 379, 384, 399, 279, 289, 276, 268, 271, 223, 170, 150, 154, 177, 140, 126, 114, 121, 97, 86, 80, 59, 48, 44, 43, 28, 29, 22, 15, 13, 12, 5, 8, 5, 4, 2, 3, 7]

# %%
sp.show('seaborn-colorblind')

# %%
sp.read_local_data('구로제1동')
sp.row()
sp.show()
# Out:
# [197, 212, 193, 227, 211, 226, 229, 211, 237, 198, 233, 218, 221, 191, 193, 198, 177, 206, 242, 233, 244, 259, 239, 261, 247, 253, 284, 316, 271, 298, 345, 343, 342, 402, 383, 468, 456, 495, 412, 430, 372, 400, 378, 338, 411, 363, 380, 356, 376, 316, 329, 312, 286, 284, 315, 288, 315, 321, 338, 307, 344, 310, 293, 290, 271, 206, 216, 147, 130, 131, 133, 116, 125, 86, 92, 72, 90, 72, 76, 58, 46, 49, 41, 41, 35, 34, 26, 15, 24, 15, 11, 14, 9, 6, 3, 6, 3, 4, 4, 1, 1]

# %%
sp.read_local_data('삼청동')
sp.show()

# %%
sp.read_local_data('삼성동')
sp.row()
sp.show()
# Out:
# [484, 542, 573, 667, 664, 668, 746, 750, 812, 737, 804, 918, 885, 863, 911, 1002, 1008, 1139, 1323, 1284, 1288, 1347, 1422, 1367, 1317, 1342, 1310, 1313, 1175, 1083, 1039, 1005, 1005, 1052, 1046, 1158, 1320, 1328, 1402, 1313, 1294, 1375, 1397, 1447, 1677, 1721, 1740, 1854, 1871, 1882, 1956, 1740, 1721, 1751, 1700, 1551, 1798, 1809, 1842, 1730, 1516, 1394, 1331, 1317, 1201, 961, 1062, 840, 878, 864, 772, 860, 775, 565, 605, 549, 744, 632, 516, 478, 477, 405, 348, 329, 267, 208, 186, 150, 147, 124, 98, 70, 54, 37, 25, 31, 20, 10, 5, 4, 39]
